# %%
import os
import numpy as np
import pandas as pd
import torch
import torchvision.transforms as transforms
import torchvision.models as models
from PIL import Image
from sklearn.model_selection import train_test_split

def extract_features(image_paths):
    # Load a pre-trained ResNet model
    resnet = models.resnet18(pretrained=True)
    # Remove the classification layer (the last layer) to get feature vectors
    resnet_feature_extractor = torch.nn.Sequential(*list(resnet.children())[:-1])
    # Set the model to evaluation mode
    resnet_feature_extractor.eval()

    features = []
    for img_path in image_paths:
        try:
            # Open and preprocess the image
            img = Image.open(img_path).convert('RGB')
            preprocess = transforms.Compose([
                transforms.Resize(256),
                transforms.CenterCrop(224),
                transforms.ToTensor(),
                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
            ])
            img_tensor = preprocess(img)
            img_tensor = img_tensor.unsqueeze(0)  # Add batch dimension

            # Extract features
            with torch.no_grad():
                feature_vector = resnet_feature_extractor(img_tensor)
            features.append(feature_vector.squeeze().numpy())
        except (OSError, Exception) as e:
            print("Skipping image:", img_path)
            print("Error:", e)

    return features

# Define your dataset directory
dataset_dir = r"Dataset"

# Get list of class folders
class_folders = [folder for folder in os.listdir(dataset_dir) if os.path.isdir(os.path.join(dataset_dir, folder))]

# Prepare data and labels
data = []
labels = []
image_count = 0
for i, folder in enumerate(class_folders):
    class_dir = os.path.join(dataset_dir, folder)
    image_files = [os.path.join(class_dir, file) for file in os.listdir(class_dir) if file.endswith(('.jpg', '.jpeg', '.png'))]
    image_count += len(image_files)
    features = extract_features(image_files)
    data.extend(features)
    labels.extend([i]*len(features))

print("Total number of images in the dataset:", image_count)
print("Number of features extracted:", len(data))

data = np.array(data)
labels = np.array(labels)

X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)
# Out:
# C:\Users\dhede\AppData\Roaming\Python\Python311\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\dhede\AppData\Roaming\Python\Python311\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Barong Indo\15.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Barong Indo\\15.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\100.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\100.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\101.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\101.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\103.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\103.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\104.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\104.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\105.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\105.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\107.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\107.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\108.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\108.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\110.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\110.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\111.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\111.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\112.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\112.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\113.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\113.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\114.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\114.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\116.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\116.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\117.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\117.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\118.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\118.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\119.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\119.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\120.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\120.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\129.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\129.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\130.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\130.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\132.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\132.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\133.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\133.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\135.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\135.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\136.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\136.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\139.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\139.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\140.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\140.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\141.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\141.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\143.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\143.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\144.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\144.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\146.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\146.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\151.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\151.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\152.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\152.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\153.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\153.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\155.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\155.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\156.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\156.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\163.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\163.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\165.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\165.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\170.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\170.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\172.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\172.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\175.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\175.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\180.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\180.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\182.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\182.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\184.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\184.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\185.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\185.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\186.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\186.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\188.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\188.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\196.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\196.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\207.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\207.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\208.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\208.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\212.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\212.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\214.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\214.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\217.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\217.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\218.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\218.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\219.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\219.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\22.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\22.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\220.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\220.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\222.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\222.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\223.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\223.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\225.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\225.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\229.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\229.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\232.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\232.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\233.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\233.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\236.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\236.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\24.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\24.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\241.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\\241.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Fandango\243.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Fandango\
jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\715.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\715.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\718.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\718.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\719.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\719.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\72.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\72.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\720.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\720.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\721.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\721.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\722.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\722.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\724.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\724.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\725.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\725.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\726.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\726.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\727.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\727.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\728.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\728.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\729.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\729.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\730.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\730.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\732.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\732.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\733.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\733.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\735.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\735.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\738.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\738.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\74.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\74.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\741.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\741.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\745.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\745.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\747.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\747.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\749.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\749.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\75.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\75.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\750.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\750.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\751.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\751.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\752.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\752.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\753.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\753.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\754.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\754.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\756.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\756.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\760.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\760.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\763.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\763.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\764.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\764.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\767.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\767.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\768.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\768.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\769.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\769.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\770.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\770.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\79.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\79.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\81.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\81.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\82.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\82.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\83.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\83.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\84.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\84.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\87.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\87.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\88.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\88.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\89.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\89.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\90.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\90.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\95.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\95.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\96.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\96.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Manipuri\99.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Manipuri\\99.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Philiipines\10.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Philiipines\\10.jpg'
# Skipping image: C:\Users\dhede\OneDrive\Desktop\SEM IV\ML\Projectwork\Dataset\Philiipines\9.jpg
# Error: cannot identify image file 'C:\\Users\\dhede\\OneDrive\\Desktop\\SEM IV\\ML\\Projectwork\\Dataset\\Philiipines\\9.jpg'
# Total number of images in the dataset: 9600
# Number of features extracted: 8790

# %%
import numpy as np

class DecisionTree:
    def __init__(self, max_depth=None, binning_type='equal_width', num_bins=10):
        self.max_depth = max_depth
        self.binning_type = binning_type
        self.num_bins = num_bins
        self.tree = None
    
    def calculate_entropy(self, labels):
        """Calculate entropy for a list of labels."""
        unique_labels, counts = np.unique(labels, return_counts=True)
        probabilities = counts / len(labels)
        entropy = -np.sum(probabilities * np.log2(probabilities))
        return entropy

    def calculate_information_gain(self, data, labels, feature_index, threshold):
        """Calculate information gain for a specific feature and threshold."""
        true_indices = data[:, feature_index] <= threshold
        false_indices = ~true_indices
        true_labels = labels[true_indices]
        false_labels = labels[false_indices]
        parent_entropy = self.calculate_entropy(labels)
        true_entropy = self.calculate_entropy(true_labels)
        false_entropy = self.calculate_entropy(false_labels)
        true_weight = len(true_labels) / len(labels)
        false_weight = len(false_labels) / len(labels)
        information_gain = parent_entropy - (true_weight * true_entropy + false_weight * false_entropy)
        return information_gain

    def binning(self, data, num_bins=None, binning_type=None):
        """Perform binning on continuous data."""
        if binning_type is None:
            binning_type = self.binning_type
        if num_bins is None:
            num_bins = self.num_bins

        if len(data) == 0:
            raise ValueError("Data array is empty.")

        if binning_type == 'equal_width':
            min_val = np.min(data)
            max_val = np.max(data)
            if min_val == max_val:
                # Handle the case when all values are the same
                bins = np.linspace(min_val, max_val + 1, num_bins + 1)
            else:
                bins = np.linspace(min_val, max_val, num_bins + 1)
        elif binning_type == 'equal_frequency':
            bins = np.percentile(data, np.linspace(0, 100, num_bins + 1))
        else:
            raise ValueError("Invalid binning type. Choose 'equal_width' or 'equal_frequency'.")
        binned_data = np.digitize(data, bins)
        return binned_data, bins
    
    def find_best_split(self, data, labels):
        """Find the best split using information gain."""
        num_features = data.shape[1]
        best_information_gain = -1
        best_feature_index = None
        best_threshold = None

        for feature_index in range(num_features):
            feature_values = data[:, feature_index]
            if len(np.unique(feature_values)) == 1:
                continue  # Skip if there's only one unique value
            
            if np.issubdtype(data.dtype, np.number):
                # Continuous feature, perform binning
                binned_data, bins = self.binning(feature_values)
                for threshold in bins[1:-1]:
                    true_indices = feature_values <= threshold
                    information_gain = self.calculate_information_gain(data, labels, feature_index, threshold)
                    if information_gain > best_information_gain:
                        best_information_gain = information_gain
                        best_feature_index = feature_index
                        best_threshold = threshold
            else:
                # Categorical feature
                unique_values = np.unique(feature_values)
                for value in unique_values:
                    indices = feature_values == value
                    information_gain = self.calculate_information_gain(data, labels, feature_index, value)
                    if information_gain > best_information_gain:
                        best_information_gain = information_gain
                        best_feature_index = feature_index
                        best_threshold = value
    
        return best_feature_index, best_threshold
    def fit(self, X, y, depth=0):
        """Build the Decision Tree recursively."""
        if len(X) == 0 or len(y) == 0:  # Check if X or y is empty
            return None  # Handle empty data gracefully

        if depth == self.max_depth or len(np.unique(y)) == 1:
            return np.argmax(np.bincount(y))

        best_feature_index, best_threshold = self.find_best_split(X, y)
        if best_feature_index is None:
            return np.argmax(np.bincount(y))

        if depth == 0:
            print("Principle Root Node: Feature Index =", best_feature_index, ", Threshold =", best_threshold)

        if np.issubdtype(X.dtype, np.number):
            # Continuous feature
            binned_data, _ = self.binning(X)
            true_indices = binned_data[:, best_feature_index] <= best_threshold
        else:
            # Categorical feature
            true_indices = X[:, best_feature_index] == best_threshold

        X_true, y_true = X[true_indices], y[true_indices]
        X_false, y_false = X[~true_indices], y[~true_indices]

        subtree = {}
        subtree[(best_feature_index, best_threshold, True)] = self.fit(X_true, y_true, depth + 1)
        subtree[(best_feature_index, best_threshold, False)] = self.fit(X_false, y_false, depth + 1)

        return subtree

    def predict_sample(self, sample):
        """Predict the class label for a single sample."""
        node = self.tree
        while isinstance(node, dict):
            feature_index, threshold, direction = list(node.keys())[0]
            if np.issubdtype(sample.dtype, np.number):
                if sample[feature_index] <= threshold:
                    node = node[(feature_index, threshold, True)]
                else:
                    node = node[(feature_index, threshold, False)]
            else:
                if sample[feature_index] == threshold:
                    node = node[(feature_index, threshold, True)]
                else:
                    node = node[(feature_index, threshold, False)]
        return node

    def predict(self, X):
        """Predict class labels for multiple samples."""
        return [self.predict_sample(sample) for sample in X]

dt = DecisionTree(max_depth=3, binning_type='equal_width', num_bins=5)
dt.tree = dt.fit(X_train, y_train)
# Out:
# Principle Root Node: Feature Index = 252 , Threshold = 1.7924240112304688
